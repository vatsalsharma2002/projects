# %% [markdown]
# <a href="https://colab.research.google.com/github/vatsalsharma2002/projects/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
message1 = "I'm gonna be a master of this language, example string using single quotation '"
print(message1)

message2 = 'Vice Versa for "previous example with double quotations"'
print(message2)

message3 = 'This will give length of string or total number of characters'
print(len(message3))

message4 = 'This will index and individual character of this string '
print(message4[0])

message5 = 'Using upper and lower cases'
print(message5.lower())
print(message5.upper())
print(message5.count('u'))
print(message5.count('upper'))
print(message5[0:6])
print(message5[6:])
print(message5.find('upper'))

message5 = message5.replace('Using','Replacing')
print(message5)


concept = 'placeholders'
what_are_they = 'curly brackets'

message6 = f'{concept}, {what_are_they}. These are used to combine different string together'
print(message6)
# Out:
# I'm gonna be a master of this language, example string using single quotation '
# Vice Versa for "previous example with double quotations"
# 61
# T
# using upper and lower cases
# USING UPPER AND LOWER CASES
# 1
# 1
# Using
# upper and lower cases
# 6
# Replacing upper and lower cases
# placeholders, curly brackets. These are used to combine different string together
